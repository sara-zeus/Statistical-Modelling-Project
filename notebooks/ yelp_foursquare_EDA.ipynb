# %%
import requests
import pandas as pd

# %%
df_city_bikes = pd.read_csv("data.csv")

# %%
df_city_bikes
# Out:
#       Unnamed: 0   Latitude  Longitude  Available Bikes  Empty Slots  \
# 0              0  48.865983   2.275725                1           29
# 1              1  48.853756   2.339096                0           52
# 2              2  48.867872   2.364898                4           12
# 3              3  48.856452   2.334852                2           13
# 4              4  48.879296   2.337360                1           20
# ...          ...        ...        ...              ...          ...
# 1455        1455  48.939959   2.327957               13            1
# 1456        1456  48.936094   2.343617               11            1
# 1457        1457  48.832024   2.490271                4            1
# 1458        1458  48.880598   2.376949                0           27
# 1459        1459  48.836919   2.391678                2            5
#
#        Station ID
# 0       213688169
# 1        99950133
# 2       312165511
# 3       210405211
# 4           36255
# ...           ...
# ...

# %%
lat_long_list = []
for index, row in df_city_bikes.iterrows():
    lat_long_pair = f"{row['Latitude']},{row['Longitude']}"
    lat_long_list.append(lat_long_pair)

# %% [markdown]
# ## Connect to the Foursquare API

# %%
import requests

my_foursquare_list = [] 

for i in lat_long_list[:200]:
    url = 'https://api.foursquare.com/v3/places/search'
    params = {
    'll': i,
       # add cattg
        #change radius to 1000 
    'radius': '1500'
    }
    headers = {
    'Authorization': 'fsq3NdGSIa5Ad+xZqw2h+60RA6anmjwqN7nG23mecDcLMdk='
    }

    response = requests.get(url, headers=headers, params=params)

    if response.status_code == 200:
        response_json = response.json()
        my_foursquare_list.append(response_json) 

        
    
    else:
        print(f"Error: {response.status_code}")

# %%
len(my_foursquare_list)
# Out:
# 200

# %% [markdown]
# ## Testing

# %%
# my_foursquare_list[1]['results'][0]['categories'][0]['name']

# %%
# my_foursquare_list[2]['results'][0]

# %%
# my_foursquare_list[1]['results'][0]['categories'][0]['short_name']

# %%
# category_list = []
# formatted_address_list = []
# country_list = []
# locality_list = []
# region_list = []
# type_list = [] 
# name_list = []


# for i in my_foursquare_list:
#     try:
#         category_list.append(i['results'][0]['categories'][0]['name']) 
#     except (KeyError, IndexError):
#         category_list.append(None)  # Appending None or any default value when key/index is missing
    
#     try:
#         formatted_address_list.append(i['results'][0]['location']['formatted_address'])
#     except (KeyError, IndexError):
#         formatted_address_list.append(None)
    
#     try:
#         country_list.append(i['results'][0]['location']['country'])
#     except (KeyError, IndexError):
#         country_list.append(None)
    
#     try:
#         locality_list.append(i['results'][0]['location']['locality'])
#     except (KeyError, IndexError):
#         locality_list.append(None)
    
#     try:
#         region_list.append(i['results'][0]['location']['region'])
#     except (KeyError, IndexError):
#         region_list.append(None)
    
#     try:
#         type_list.append(i['results'][0]['categories'][1]['name'])
#     except (KeyError, IndexError):
#         type_list.append(None)
        
#     try:
#         name_list.append(i['results'][0]['categories'][2]['name'])
#     except (KeyError, IndexError):
#         name_list.append(None) 
        
        
    
        
        
        
        

# print(name_list)

# %% [markdown]
# ## Creating a foursquare dataframe

# %%
foursquare_pd = pd.DataFrame() 

for i in range(len(my_foursquare_list)):
    normalized_results = pd.json_normalize(my_foursquare_list[i]['results'])
    foursquare_pd = pd.concat([foursquare_pd, normalized_results], ignore_index=True)

# %%
foursquare_pd.head(100)
# Out:
#                       fsq_id  \
# 0   57caabf0cd107656b7a22851
# 1   4b1ff559f964a520592b24e3
# 2   628f3fb0f6e50f2be3a6711b
# 3   4bd2d23541b9ef3bdabcfee5
# 4   5bf2afc17e210b0025f5f0ed
# ..                       ...
# 95  4d602544865a224b2091a785
# 96  4b06936bf964a52051ed22e3
# 97  4f6081bce4b0382505fcc3ae
# 98  4b1f9255f964a520052724e3
# 99  51aa304a498ed5e684f787d3
#
#                                            categories chains   closed_bucket  \
# 0   [{'id': 13034, 'name': 'Café', 'short_name': '...     []  VeryLikelyOpen
# 1   [{'id': 13057, 'name': 'Gastropub', 'short_nam...     []  VeryLikelyOpen
# 2   [{'id': 13035, 'name': 'Coffee Shop', 'short_n...     []      LikelyOpen
# 3   [{'id': 13002, 'name': 'Bakery', 'short_name':...     []      LikelyOpen
# 4   [{'id': 13065, 'name': 'Restaurant', 'short_na...     []      LikelyOpen
# ..                                                ...    ...             ...
# ...

# %%
foursquare_pd['Categories'] = my_foursquare_list[i]['results'][0]['categories'][0]['name']

# %%
foursquare_pd['Station ID'] = df_city_bikes['Station ID']

# %%
foursquare_pd.head(100)
# Out:
#                       fsq_id  \
# 0   57caabf0cd107656b7a22851
# 1   4b1ff559f964a520592b24e3
# 2   628f3fb0f6e50f2be3a6711b
# 3   4bd2d23541b9ef3bdabcfee5
# 4   5bf2afc17e210b0025f5f0ed
# ..                       ...
# 95  4d602544865a224b2091a785
# 96  4b06936bf964a52051ed22e3
# 97  4f6081bce4b0382505fcc3ae
# 98  4b1f9255f964a520052724e3
# 99  51aa304a498ed5e684f787d3
#
#                                            categories chains   closed_bucket  \
# 0   [{'id': 13034, 'name': 'Café', 'short_name': '...     []  VeryLikelyOpen
# 1   [{'id': 13057, 'name': 'Gastropub', 'short_nam...     []  VeryLikelyOpen
# 2   [{'id': 13035, 'name': 'Coffee Shop', 'short_n...     []      LikelyOpen
# 3   [{'id': 13002, 'name': 'Bakery', 'short_name':...     []      LikelyOpen
# 4   [{'id': 13065, 'name': 'Restaurant', 'short_na...     []      LikelyOpen
# ..                                                ...    ...             ...
# ...

# %%
len(foursquare_pd)
# Out:
# 2000

# %% [markdown]
# ## Connect to the Yelp API.

# %%
import requests


my_yelp_list = []
for location in lat_long_list[:200]:
    
    lat_lon = location.split(",")
    lat = float(lat_lon[0])
    lon = float(lat_lon[1])

    
    url = 'https://api.yelp.com/v3/businesses/search'
    params = {
        'latitude': lat,
        'longitude': lon,
        'radius': '1500'  
    }
    headers = {
        'Authorization': 'Bearer OtqFQieov52oe2O9nGe8LTBRLNTBX2IYDlu09rIT6vJQz4kXeg1YrVAQze7zNhThJ74bPR06mPSFKulGQ_09Fr_AaHTUQ3viOxSMYKx9kxB3UbwndfQga7A37wJXZXYx'
    }

    response_yelp = requests.get(url, headers=headers, params=params)
    

    if response_yelp.status_code == 200:
        response_yelp_json = response_yelp.json()
        my_yelp_list.append(response_yelp_json)

# %%
yelp_pd = pd.DataFrame()  

for i in range(len(my_yelp_list)):
    normalized_businesses = pd.json_normalize(my_yelp_list[i]['businesses'])
    yelp_pd = pd.concat([yelp_pd, normalized_businesses], ignore_index=True)

# %%
len(yelp_pd)
# Out:
# 4000

# %%
yelp_pd['Station ID'] = df_city_bikes['Station ID']

# %%
my_yelp_list[0]['businesses'][0]['categories'][0]['alias']
# Out:
# 'french'

# %%
Final_pd = pd.merge(yelp_pd, foursquare_pd, on='Station ID',how='inner')

# %%
pd.set_option('display.max_columns', None)  

Final_pd.head(1)
# Out:
#             name  rating  review count price  \
# 0  Le Zinc du 16     4.5           511    €€
#
#                                           categories  \
# 0  [{'id': 13034, 'name': 'Café', 'short_name': '...
#
#                     address         region   city country          status  \
# 0  58 rue de la Faisanderie  Île-de-France  Paris      FR  VeryLikelyOpen
#
#     Station ID  coordinates latitude  coordinates longitude
# 0  213688169.0             48.868105               2.284365

# %% [markdown]
# deleting unwanted columns

# %%
Final_pd.drop(columns=['id','image_url'], inplace=True)

Final_pd.drop(columns=['url','phone','display_phone'], inplace=True)
Final_pd.drop(columns=['related_places.children','related_places.parent.name','related_places.parent.categories','related_places.parent.fsq_id'], inplace=True) 

Final_pd.drop(columns=['location.postcode','location.cross_street','geocodes.roof.latitude','geocodes.roof.longitude','geocodes.drop_off.longitude','timezone'], inplace=True)

# %%
Final_pd.drop(columns=['distance_x','location.address2','location.address3'], inplace=True)
Final_pd.drop(columns=['chains'], inplace=True)

Final_pd.drop(columns=['transactions'], inplace=True)


Final_pd.drop(columns=['location.admin_region'], inplace=True)

Final_pd.drop(columns=['is_closed','location.locality'], inplace=True)

Final_pd.drop(columns=['location.country_y'], inplace=True)

Final_pd.drop(columns=['alias'], inplace=True)

Final_pd.drop(columns=['location.address1','location.zip_code','location.state','location.display_address','fsq_id','distance_y','link','location.formatted_address'], inplace=True)


Final_pd.drop(columns=['geocodes.main.longitude','geocodes.main.latitude','geocodes.drop_off.latitude'], inplace=True)

# %%
Final_pd.drop(columns=['name_x','categories_x'], inplace=True)

# %%
Final_pd.drop(columns=['Categories'], inplace=True)

# %% [markdown]
# Renaming cells

# %%
Final_pd.rename(columns={'review_count':'review count','coordinateslatitude':'coordinates latitude','coordinates.longitude':'coordinates longitude'}, inplace=True)
Final_pd.rename(columns={'location.city':'city','location.country_x':'country','categories_y':'categories'}, inplace=True)
Final_pd.rename(columns={'closed_bucket':'status', 'name_y':'name','location.address':'address','location.region':'region'}, inplace=True)

# %% [markdown]
# Ordering columns

# %%
desired_order = ['name','rating','review count','price','categories','address','region','city','country','status','Station ID','coordinates latitude','coordinates longitude'] 

Final_pd = Final_pd[desired_order]

# %%
Final_pd['categories'] = Final_pd['categories'][i][0]['name']
# Out:
# 'Café'

# %%
for i in range(len(Final_pd)):
    try:
        category_name = Final_pd['categories'][i][0]['name']
        Final_pd.at[i, 'categories'] = category_name
    except (KeyError, IndexError):
        Final_pd.at[i, 'categories'] = None

# %% [markdown]
# Adding the Number of Available Bikes to my dataframe

# %%
Final_pd['Number of Available Bikes'] = df_city_bikes['Available Bikes']

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
Final_pd.to_csv('Final_pd.csv')

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
import pandas as pd

df = pd.read_csv('final_data.csv') 

df.drop(columns=['Unnamed: 0'], inplace=True)

df.dropna(axis=0, how='any', inplace=True)

df
# Out:
#                                 name  rating  review count price  \
# 0                      Le Zinc du 16     4.5           511    €€
# 1                        Le Flandrin     4.5           241   €€€
# 3                              Béchu     4.0           150    €€
# 4                   Restaurant Brach     5.0            41    €€
# 5                   Saint-James Club     5.0            64   €€€
# ...                              ...     ...           ...   ...
# 1455               Cirque Electrique     4.5           120  €€€€
# 1456              Au Métro des Lilas     5.0            11    €€
# 1457                       CGR Paris     4.0           251  €€€€
# 1458  Théâtre National de la Colline     4.0           400  €€€€
# 1459                 La Maroquinerie     4.0            77   €€€
#
#          categories                        address         region   city  \
# 0              Café       58 rue de la Faisanderie  Île-de-France  Paris
# ...

# %%
sorted_df = df.sort_values(by='rating', ascending=False)

# %%
sorted_df.head(10)
